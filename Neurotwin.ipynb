# %% [markdown]
# <a href="https://colab.research.google.com/github/aryan12375/Neurotwin/blob/main/Neurotwin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the repository
# !git clone https://github.com/aryan12375/Neurotwin.git
# %cd Neurotwin

# 2. Install dependencies
# (We skip PySide6 because Colab doesn't support desktop GUI windows)
# !pip install torch pandas numpy scikit-learn matplotlib

# 3. Run the main training and simulation script
# Use %run instead of !python to show the graphs inline
# %run main.py
# Out:
# Cloning into 'Neurotwin'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 35 (delta 3), reused 30 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 598.97 KiB | 24.96 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/Neurotwin/Neurotwin
# ...
# NeuroTwinLatent(
#   (encoder): LSTM(1, 128, batch_first=True)
#   (fc_mu): Linear(in_features=128, out_features=64, bias=True)
#   (fc_logvar): Linear(in_features=128, out_features=64, bias=True)
#   (fc_latent): Linear(in_features=64, out_features=128, bias=True)
#   (decoder): LSTM(1, 128, batch_first=True)
#   (fc_out): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch [1/50] | Train Loss: 0.054520 | Val Loss: 0.021851
# Epoch [2/50] | Train Loss: 0.025944 | Val Loss: 0.018721
# Epoch [3/50] | Train Loss: 0.023692 | Val Loss: 0.019034
# Epoch [4/50] | Train Loss: 0.023244 | Val Loss: 0.017591
# ...
